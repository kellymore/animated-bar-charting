# %% [markdown]
# ## Load Libaries

# %%
import pandas as pd
import os

# %% [markdown]
# ## Load dataset from local

# %%
os.chdir('/Users/kelly/Downloads/')
data_cor = pd.read_csv("anima_chart.csv")
data_cor.head()
# Out:
#          date  Afghanistan  Albania  Algeria  Andorra  Angola  \
# 0  01/22/2020          353       14      207       10     225
# 1  01/23/2020          280      354      243      305       4
# 2  01/24/2020          273      253      368       53     362
# 3  01/25/2020          466      398      394      149     480
# 4  01/26/2020          378        3      441      335     136
#
#    Antigua and Barbuda  Argentina  Armenia  Australia  ...  United States  \
# 0                   66        240       56        226  ...            272
# 1                  466        482       24        424  ...             89
# 2                  103        123       38        232  ...            336
# 3                  295        463      485         22  ...            393
# 4                  442        297      232        452  ...            304
#
#    Uruguay  Uzbekistan  Vanuatu  Vatican City  Venezuela  Vietnam  Yemen  \
# ...

# %%
cols = ['date', 'Italy', 'China', 'Australia', 'Brazil', 'India', 'United Kingdom']

Subsetdf = data_cor[cols]
Subsetdf.set_index("date", inplace= True)

cum_sum_df = Subsetdf.cumsum(axis=0)
cum_sum_df.tail(10)
# Out:
#             Italy  China  Australia  Brazil  India  United Kingdom
# date
# 01/11/2021  86952  87979      87031   91419  88419           92354
# 01/12/2021  87194  87997      87262   91644  88706           92844
# 01/13/2021  87197  88347      87412   91882  88903           93055
# 01/14/2021  87454  88711      87879   92130  89100           93509
# 01/15/2021  87699  89055      87993   92536  89384           93915
# 01/16/2021  88111  89283      88466   92885  89388           93921
# 01/17/2021  88592  89660      88736   93335  89476           94150
# 01/18/2021  88925  89869      89196   93378  89485           94460
# 01/19/2021  89057  90321      89514   93530  89606           94897
# 01/20/2021  89115  90803      89794   93711  89999           95084

# %% [markdown]
# ## Racing bar plot
#
# Press play after running. Download or adjust playback speed as desired. The length of the animation is dependent on the size of the data being visualized.

# %%
import bar_chart_race as bcr
bcr.bar_chart_race(df=cum_sum_df, filename=None, figsize=(3,5), title='Cases by Country')
